# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from gc import collect as collect_garbage
from psutil import virtual_memory
from os import scandir

# %%
folder = "D:/nicu-hrv-data/01-rpeaks/"
files = [file.name for file in scandir(folder)]

# %%
print(files)
# Out:
# ['rpeaks_1a.csv', 'rpeaks_1b.csv', 'rpeaks_1c.csv', 'rpeaks_1d.csv', 'rpeaks_1e.csv', 'rpeaks_2a.csv', 'rpeaks_2b.csv', 'rpeaks_2c.csv', 'rpeaks_2d.csv', 'rpeaks_2e.csv', 'rpeaks_3a.csv', 'rpeaks_3b.csv', 'rpeaks_3c.csv', 'rpeaks_3d.csv', 'rpeaks_3e.csv', 'rpeaks_4a.csv', 'rpeaks_4b.csv', 'rpeaks_4c.csv', 'rpeaks_4d.csv', 'rpeaks_4e.csv', 'rpeaks_5a.csv', 'rpeaks_5b.csv', 'rpeaks_5c.csv', 'rpeaks_5d.csv', 'rpeaks_5e.csv', 'rpeaks_6a.csv', 'rpeaks_6b.csv', 'rpeaks_6c.csv', 'rpeaks_6d.csv', 'rpeaks_6e.csv', 'rpeaks_7a.csv', 'rpeaks_7b.csv', 'rpeaks_7c.csv', 'rpeaks_7d.csv', 'rpeaks_7e.csv']

# %%
# All this loop does is load in a file as a dataframe, and then deletes it.
# The purpose of this is to see if I can actually access the files.append
for file in files:
    df = pd.read_csv(folder + file)
    print(df.head())
    print()
    del df
    collect_garbage()
# Out:
#             time
# 0  345600.265306
# 1  345600.642058
# 2  345601.010424
# 3  345601.393469
# 4  345601.779318
#
#             time
# 0  604800.690110
# 1  604801.063627
# 2  604801.454883
# 3  604801.851858
# 4  604802.229748
#
#             time
# 0  864000.397569
# 1  864000.773004
# 2  864001.144241
# 3  864001.506307
# 4  864001.879821
#
#            time
# 0  1.123201e+06
# 1  1.123201e+06
# 2  1.123201e+06
# 3  1.123202e+06
# 4  1.123202e+06
#
#            time
# 0  1.382400e+06
# 1  1.382401e+06
# 2  1.382401e+06
# 3  1.382401e+06
# 4  1.382402e+06
#
#            time
# 0  4.752001e+06
# 1  4.752001e+06
# 2  4.752001e+06
# 3  4.752002e+06
# 4  4.752002e+06
#
#            time
# 0  5.011201e+06
# 1  5.011201e+06
# 2  5.011201e+06
# 3  5.011202e+06
# 4  5.011202e+06
#
#            time
# 0  5.270401e+06
# 1  5.270401e+06
# 2  5.270402e+06
# 3  5.270402e+06
# 4  5.270403e+06
#
#            time
# 0  5.529600e+06
# 1  5.529601e+06
# 2  5.529601e+06
# 3  5.529601e+06
# ...
